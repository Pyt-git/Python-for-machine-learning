# %%
# Notebook overview
# This notebook builds the softmax function used to compute attention scores in a Transformer.
# Softmax prevents overflow and stabilizes the output. 

import numpy as np
from src.softmax import softmax

# test case
print("--- Test 1: Standard 1D Vector ---")
logits_1d = np.array([2.0, 1.0, 0.1])
probs_1d = softmax(logits_1d)
print(f"Logits: {logits_1d}")
print(f"Probabilities: {probs_1d}")
print(f"Sums to 1.0: {np.isclose(np.sum(probs_1d), 1.0)}")
