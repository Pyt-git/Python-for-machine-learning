# %%
# This notebook builds the Transformer block model used to build the final Transformer
# It includes dropout, LayerNorm (LN), feedforward networking (ffn), softmax and multihead attention (MHA)

import numpy as np
from src.transformer-model import transformer_block
